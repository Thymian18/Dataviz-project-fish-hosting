# %%
import pandas as pd
import plotly.express as pt
import dataLoadingHelper as dlh

sheets_dict = pd.read_excel('data/angling.xlsx', sheet_name=None)  # Reads all sheets
cleaned_sheets = dlh.makeCleanedSheetDictionary(sheets_dict)

# Example: Access cleaned data for a specific year
df_2021 = cleaned_sheets.get('2021')
df_2021
# Out:
# 0                 Lake   LakeArea   Total Aal Agone Seeforelle Übrige  \
# 1                Total        NaN  231931  21   482       7393     86
# 2            Genfersee  345,4 km²   44371   0     0       1904      0
# 3       Neuenburgersee  215,0 km²   24322   0     0        707      0
# 4           Bodensee 2  172,6 km²   17842  14     0        482     43
# 5   Vierwaldstättersee  113,7 km²   13869   0     0       1410     31
# 6          Zürichsee 3   88,1 km²   28277   7     0        533      0
# 7            Thunersee   47,7 km²    6022   0     0        593      0
# 8        Lago Maggiore   40,8 km²    4258   0   471        477      0
# 9            Bielersee   39,4 km²   24315   0     0          3      0
# 10            Zugersee   38,4 km²   19871   0     0        413      0
# 11          Luganersee   30,0 km²   12428   0    11        252      0
# 12         Brienzersee   29,7 km²    1427   0     0        334      0
# ...

# %%
# Call the function to plot

timeseriesZugersee, years = dlh.LakeTimeseries(cleaned_sheets, 'Zugersee', [2010, 2021])
timeseriesZürichsee, years = dlh.LakeTimeseries(cleaned_sheets, 'Vierwaldstättersee', [2010, 2021])

dlh.plot_lake_timeseries(years, timeseriesZugersee, 'Zugersee')
dlh.plot_lake_timeseries(years, timeseriesZürichsee, 'Vierwaldstättersee')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 timeseriesZugersee, years = dlh.LakeTimeseries(cleaned_sheets, 'Zugersee', [2010, 2021])
#       4 timeseriesZürichsee, years = dlh.LakeTimeseries(cleaned_sheets, 'Vierwaldstättersee', [2010, 2021])
# ----> 6 dlh.plot_lake_timeseries(years, timeseriesZugersee, 'Zugersee')
#       7 dlh.plot_lake_timeseries(years, timeseriesZürichsee, 'Vierwaldstättersee')
#
# File ~/Documents/EPFL/MA2/Dataviz/project/Dataviz-project-fish/dataLoadingHelper.py:41, in plot_lake_timeseries(years, timeseries, lake_name)
#      40 def plot_lake_timeseries(years, timeseries, lake_name):
# ---> 41     df = pd.DataFrame({'Year': years, 'Seeforelle': timeseries})
#      43     fig = px.line(df, x='Year', y='Seeforelle',
#      44                   title=f'Seeforelle Population in {lake_name} Over Time',
# ...

# %%
import folium
import geopandas as gpd

# Define Swiss lakes data (replace with actual values)
lakes_data = {
    "Genfersee": {"lat": 46.4500, "lon": 6.5833, "fish_count": 63845},
    "Neuenburgersee": {"lat": 46.925, "lon": 6.85, "fish_count": 23502},
    "Bodensee": {"lat": 47.5, "lon": 9.3, "fish_count": 172600}
}

# Create a base map centered in Switzerland
swiss_map = folium.Map(location=[46.8, 8.3], zoom_start=7)

# Add bubbles for each lake
for lake, data in lakes_data.items():
    folium.CircleMarker(
        location=[data["lat"], data["lon"]],
        radius=data["fish_count"] / 10000,  # Scale bubble size
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.6,
        popup=f"{lake}: {data['fish_count']} fish"
    ).add_to(swiss_map)

# Save map and display
swiss_map.save("swiss_lakes_map.html")
